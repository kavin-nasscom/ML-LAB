# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt

import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import SGD

# %% [markdown]
# #### Equations for Forward Propagation:
#
# 1. **Input to Hidden Layer:**
#    $$ Z^{[1]} = X \cdot W^{[1]} + b^{[1]} $$
#    $$ A^{[1]} = \text{ReLU}(Z^{[1]}) $$
#
# 2. **Hidden Layer to Output:**
#    $$ Z^{[2]} = A^{[1]} \cdot W^{[2]} + b^{[2]} $$
#    $$ A^{[2]} = \text{softmax}(Z^{[2]}) $$
#
# #### Equations for Backward Propagation:
#
# 1. **Output Layer:**
#    $$ dZ^{[2]} = A^{[2]} - Y $$
#    $$ dW^{[2]} = \frac{1}{m} \cdot A^{[1]T} \cdot dZ^{[2]} $$
#    $$ db^{[2]} = \frac{1}{m} \cdot \text{np.sum}(dZ^{[2]}, axis=0, keepdims=True) $$
#
# 2. **Hidden Layer:**
#    $$ dZ^{[1]} = (dZ^{[2]} \cdot W^{[2]T}) * \text{ReLU}'(Z^{[1]}) $$
#    $$ dW^{[1]} = \frac{1}{m} \cdot X^T \cdot dZ^{[1]} $$
#    $$ db^{[1]} = \frac{1}{m} \cdot \text{np.sum}(dZ^{[1]}, axis=0, keepdims=True) $$
#
# #### Parameter Update (Gradient Descent):
#    $$ W^{[l]} = W^{[l]} - \alpha \cdot dW^{[l]} $$
#    $$ b^{[l]} = b^{[l]} - \alpha \cdot db^{[l]} $$

# %% [markdown]
# #### Scratch Implementation

# %%
class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size, learning_rate=0.01):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.learning_rate = learning_rate
        
        # Initialize weights and biases
        self.W1 = np.random.randn(self.input_size, self.hidden_size)
        self.b1 = np.zeros((1, self.hidden_size))
        self.W2 = np.random.randn(self.hidden_size, self.output_size)
        self.b2 = np.zeros((1, self.output_size))
    
    def relu(self, x):
        return np.maximum(0, x)
    
    def softmax(self, x):
        exp_scores = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    
    def forward_propagation(self, X):
        # Input to Hidden Layer
        self.Z1 = np.dot(X, self.W1) + self.b1
        self.A1 = self.relu(self.Z1)
        
        # Hidden Layer to Output
        self.Z2 = np.dot(self.A1, self.W2) + self.b2
        self.A2 = self.softmax(self.Z2)
    
    def backward_propagation(self, X, y):
        m = X.shape[0]
        
        # Output Layer
        dZ2 = self.A2 - y
        dW2 = (1 / m) * np.dot(self.A1.T, dZ2)
        db2 = (1 / m) * np.sum(dZ2, axis=0, keepdims=True)
        
        # Hidden Layer
        dZ1 = np.dot(dZ2, self.W2.T) * (self.Z1 > 0).astype(float)
        dW1 = (1 / m) * np.dot(X.T, dZ1)
        db1 = (1 / m) * np.sum(dZ1, axis=0, keepdims=True)
        
        # Update weights and biases
        self.W1 -= self.learning_rate * dW1
        self.b1 -= self.learning_rate * db1
        self.W2 -= self.learning_rate * dW2
        self.b2 -= self.learning_rate * db2
    
    def train(self, X, y, epochs=200):
        for epoch in range(epochs):
            # Forward propagation
            self.forward_propagation(X)
            
            # Backward propagation
            self.backward_propagation(X, y)
            
            # Compute loss for the current epoch
            loss = self.compute_loss(X, y)
            
            # Print loss for the current epoch
            print(f'Epoch {epoch}: Loss {loss:.4f}')
    
    def compute_loss(self, X, y):
        m = X.shape[0]
        y_pred = np.argmax(self.A2, axis=1)  # Convert one-hot encoded predictions to integer labels
        log_probs = -np.log(self.A2[range(m), y_pred])  # Use y_pred instead of y
        loss = np.sum(log_probs) / m
        return loss
    
    def predict(self, X):
        self.forward_propagation(X)
        return np.argmax(self.A2, axis=1)

# %%
# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Flatten images
X_train_flat = X_train.reshape(X_train.shape[0], -1) / 255.0
X_test_flat = X_test.reshape(X_test.shape[0], -1) / 255.0

# One-hot encode labels
y_train_onehot = np.eye(10)[y_train]
y_test_onehot = np.eye(10)[y_test]

# Define neural network parameters
input_size = X_train_flat.shape[1]
hidden_size = 128
output_size = 10
learning_rate = 0.01

# Create and train the neural network
model = NeuralNetwork(input_size, hidden_size, output_size, learning_rate)
model.train(X_train_flat, y_train_onehot, epochs=200)

# Predictions on test set
predictions = model.predict(X_test_flat)
accuracy = accuracy_score(y_test, predictions)
print("Accuracy on test set:", accuracy)
# Out:
# Epoch 0: Loss 0.0122
# Epoch 1: Loss 0.0161
# Epoch 2: Loss 0.0184
# Epoch 3: Loss 0.0219
# Epoch 4: Loss 0.0239
# Epoch 5: Loss 0.0248
# Epoch 6: Loss 0.0264
# Epoch 7: Loss 0.0271
# Epoch 8: Loss 0.0274
# Epoch 9: Loss 0.0277
# Epoch 10: Loss 0.0284
# Epoch 11: Loss 0.0289
# Epoch 12: Loss 0.0299
# Epoch 13: Loss 0.0303
# Epoch 14: Loss 0.0301
# Epoch 15: Loss 0.0310
# Epoch 16: Loss 0.0314
# Epoch 17: Loss 0.0311
# Epoch 18: Loss 0.0313
# Epoch 19: Loss 0.0312
# Epoch 20: Loss 0.0317
# Epoch 21: Loss 0.0314
# Epoch 22: Loss 0.0318
# Epoch 23: Loss 0.0321
# Epoch 24: Loss 0.0319
# Epoch 25: Loss 0.0316
# Epoch 26: Loss 0.0317
# Epoch 27: Loss 0.0318
# Epoch 28: Loss 0.0321
# Epoch 29: Loss 0.0319
# Epoch 30: Loss 0.0320
# Epoch 31: Loss 0.0323
# Epoch 32: Loss 0.0328
# Epoch 33: Loss 0.0329
# Epoch 34: Loss 0.0328
# Epoch 35: Loss 0.0328
# Epoch 36: Loss 0.0326
# Epoch 37: Loss 0.0324
# Epoch 38: Loss 0.0327
# Epoch 39: Loss 0.0326
# Epoch 40: Loss 0.0326
# Epoch 41: Loss 0.0324
# Epoch 42: Loss 0.0320
# Epoch 43: Loss 0.0315
# Epoch 44: Loss 0.0314
# Epoch 45: Loss 0.0315
# Epoch 46: Loss 0.0314
# Epoch 47: Loss 0.0315
# Epoch 48: Loss 0.0314
# Epoch 49: Loss 0.0311
# Epoch 50: Loss 0.0309
# Epoch 51: Loss 0.0307
# Epoch 52: Loss 0.0306
# Epoch 53: Loss 0.0305
# Epoch 54: Loss 0.0304
# Epoch 55: Loss 0.0305
# Epoch 56: Loss 0.0304
# Epoch 57: Loss 0.0305
# Epoch 58: Loss 0.0305
# Epoch 59: Loss 0.0306
# Epoch 60: Loss 0.0306
# Epoch 61: Loss 0.0305
# Epoch 62: Loss 0.0303
# Epoch 63: Loss 0.0300
# Epoch 64: Loss 0.0298
# Epoch 65: Loss 0.0296
# Epoch 66: Loss 0.0295
# Epoch 67: Loss 0.0292
# Epoch 68: Loss 0.0289
# Epoch 69: Loss 0.0287
# Epoch 70: Loss 0.0287
# Epoch 71: Loss 0.0288
# Epoch 72: Loss 0.0289
# Epoch 73: Loss 0.0290
# Epoch 74: Loss 0.0290
# Epoch 75: Loss 0.0289
# Epoch 76: Loss 0.0287
# Epoch 77: Loss 0.0286
# Epoch 78: Loss 0.0284
# Epoch 79: Loss 0.0283
# Epoch 80: Loss 0.0283
# Epoch 81: Loss 0.0283
# Epoch 82: Loss 0.0283
# Epoch 83: Loss 0.0284
# Epoch 84: Loss 0.0283
# Epoch 85: Loss 0.0281
# Epoch 86: Loss 0.0280
# Epoch 87: Loss 0.0278
# Epoch 88: Loss 0.0276
# Epoch 89: Loss 0.0275
# Epoch 90: Loss 0.0274
# Epoch 91: Loss 0.0273
# Epoch 92: Loss 0.0272
# Epoch 93: Loss 0.0271
# Epoch 94: Loss 0.0270
# Epoch 95: Loss 0.0269
# Epoch 96: Loss 0.0268
# Epoch 97: Loss 0.0267
# Epoch 98: Loss 0.0266
# Epoch 99: Loss 0.0266
# Epoch 100: Loss 0.0266
# Epoch 101: Loss 0.0267
# Epoch 102: Loss 0.0268
# Epoch 103: Loss 0.0268
# Epoch 104: Loss 0.0268
# Epoch 105: Loss 0.0267
# Epoch 106: Loss 0.0267
# Epoch 107: Loss 0.0266
# Epoch 108: Loss 0.0265
# Epoch 109: Loss 0.0263
# Epoch 110: Loss 0.0262
# Epoch 111: Loss 0.0261
# Epoch 112: Loss 0.0261
# Epoch 113: Loss 0.0261
# Epoch 114: Loss 0.0261
# Epoch 115: Loss 0.0260
# Epoch 116: Loss 0.0260
# Epoch 117: Loss 0.0260
# Epoch 118: Loss 0.0260
# Epoch 119: Loss 0.0260
# Epoch 120: Loss 0.0260
# Epoch 121: Loss 0.0259
# Epoch 122: Loss 0.0259
# Epoch 123: Loss 0.0258
# Epoch 124: Loss 0.0257
# Epoch 125: Loss 0.0256
# Epoch 126: Loss 0.0255
# Epoch 127: Loss 0.0255
# Epoch 128: Loss 0.0254
# Epoch 129: Loss 0.0254
# Epoch 130: Loss 0.0253
# Epoch 131: Loss 0.0253
# Epoch 132: Loss 0.0254
# Epoch 133: Loss 0.0255
# Epoch 134: Loss 0.0255
# Epoch 135: Loss 0.0255
# Epoch 136: Loss 0.0254
# Epoch 137: Loss 0.0253
# Epoch 138: Loss 0.0251
# Epoch 139: Loss 0.0250
# Epoch 140: Loss 0.0249
# Epoch 141: Loss 0.0248
# Epoch 142: Loss 0.0247
# Epoch 143: Loss 0.0246
# Epoch 144: Loss 0.0246
# Epoch 145: Loss 0.0246
# Epoch 146: Loss 0.0246
# Epoch 147: Loss 0.0246
# Epoch 148: Loss 0.0246
# Epoch 149: Loss 0.0246
# Epoch 150: Loss 0.0246
# Epoch 151: Loss 0.0246
# Epoch 152: Loss 0.0246
# Epoch 153: Loss 0.0246
# Epoch 154: Loss 0.0246
# Epoch 155: Loss 0.0246
# Epoch 156: Loss 0.0246
# Epoch 157: Loss 0.0245
# Epoch 158: Loss 0.0245
# Epoch 159: Loss 0.0245
# Epoch 160: Loss 0.0245
# Epoch 161: Loss 0.0244
# Epoch 162: Loss 0.0244
# Epoch 163: Loss 0.0243
# Epoch 164: Loss 0.0243
# Epoch 165: Loss 0.0242
# Epoch 166: Loss 0.0242
# Epoch 167: Loss 0.0241
# Epoch 168: Loss 0.0241
# Epoch 169: Loss 0.0240
# Epoch 170: Loss 0.0240
# Epoch 171: Loss 0.0240
# Epoch 172: Loss 0.0240
# Epoch 173: Loss 0.0240
# Epoch 174: Loss 0.0240
# Epoch 175: Loss 0.0239
# Epoch 176: Loss 0.0239
# Epoch 177: Loss 0.0239
# Epoch 178: Loss 0.0238
# Epoch 179: Loss 0.0237
# Epoch 180: Loss 0.0236
# Epoch 181: Loss 0.0235
# Epoch 182: Loss 0.0235
# Epoch 183: Loss 0.0234
# Epoch 184: Loss 0.0234
# Epoch 185: Loss 0.0234
# Epoch 186: Loss 0.0234
# Epoch 187: Loss 0.0233
# Epoch 188: Loss 0.0233
# Epoch 189: Loss 0.0233
# Epoch 190: Loss 0.0232
# Epoch 191: Loss 0.0232
# Epoch 192: Loss 0.0231
# Epoch 193: Loss 0.0230
# Epoch 194: Loss 0.0230
# Epoch 195: Loss 0.0229
# Epoch 196: Loss 0.0229
# Epoch 197: Loss 0.0229
# Epoch 198: Loss 0.0228
# Epoch 199: Loss 0.0227
# Accuracy on test set: 0.6385

# %% [markdown]
# #### Keras Implementation

# %%
# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0

# Reshape images to flatten them
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# One-hot encode labels
y_train_onehot = to_categorical(y_train)
y_test_onehot = to_categorical(y_test)

# Define neural network parameters
input_size = X_train_flat.shape[1]
hidden_size = 128
output_size = 10
learning_rate = 0.01
epochs = 200

# Create the neural network model
model = Sequential([
    Flatten(input_shape=X_train_flat.shape[1:]),
    Dense(hidden_size, activation='relu'),
    Dense(output_size, activation='softmax')
])

# Compile the model with SGD optimizer
optimizer = SGD(learning_rate=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model
history = model.fit(X_train_flat, y_train_onehot, epochs=epochs, batch_size=32, verbose=1, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test_flat, y_test_onehot)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/200
# /home/kavin/K/sem6/ML/Lab/ml_lab/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 851us/step - accuracy: 0.7022 - loss: 1.1323 - val_accuracy: 0.8997 - val_loss: 0.3760
# Epoch 2/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 938us/step - accuracy: 0.8947 - loss: 0.3846 - val_accuracy: 0.9154 - val_loss: 0.3077
# Epoch 3/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 814us/step - accuracy: 0.9125 - loss: 0.3162 - val_accuracy: 0.9230 - val_loss: 0.2760
# Epoch 4/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 818us/step - accuracy: 0.9213 - loss: 0.2862 - val_accuracy: 0.9293 - val_loss: 0.2545
# Epoch 5/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 816us/step - accuracy: 0.9285 - loss: 0.2598 - val_accuracy: 0.9335 - val_loss: 0.2373
# Epoch 6/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 828us/step - accuracy: 0.9338 - loss: 0.2433 - val_accuracy: 0.9395 - val_loss: 0.2238
# Epoch 7/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 847us/step - accuracy: 0.9378 - loss: 0.2233 - val_accuracy: 0.9413 - val_loss: 0.2126
# Epoch 8/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step - accuracy: 0.9401 - loss: 0.2153 - val_accuracy: 0.9446 - val_loss: 0.2018
# Epoch 9/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 826us/step - accuracy: 0.9447 - loss: 0.1978 - val_accuracy: 0.9485 - val_loss: 0.1921
# Epoch 10/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 845us/step - accuracy: 0.9468 - loss: 0.1892 - val_accuracy: 0.9503 - val_loss: 0.1852
# Epoch 11/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 742us/step - accuracy: 0
200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 820us/step - accuracy: 0.9995 - loss: 0.0100 - val_accuracy: 0.9767 - val_loss: 0.0862
# Epoch 170/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 842us/step - accuracy: 0.9993 - loss: 0.0101 - val_accuracy: 0.9763 - val_loss: 0.0864
# Epoch 171/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 884us/step - accuracy: 0.9993 - loss: 0.0103 - val_accuracy: 0.9766 - val_loss: 0.0863
# Epoch 172/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - accuracy: 0.9993 - loss: 0.0099 - val_accuracy: 0.9765 - val_loss: 0.0862
# Epoch 173/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 832us/step - accuracy: 0.9994 - loss: 0.0098 - val_accuracy: 0.9764 - val_loss: 0.0865
# Epoch 174/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - loss: 0.0099 - val_accuracy: 0.9767 - val_loss: 0.0862
# Epoch 175/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 816us/step - accuracy: 0.9993 - loss: 0.0102 - val_accuracy: 0.9766 - val_loss: 0.0865
# Epoch 176/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - accuracy: 0.9994 - loss: 0.0097 - val_accuracy: 0.9767 - val_loss: 0.0861
# Epoch 177/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 895us/step - accuracy: 0.9994 - loss: 0.0101 - val_accuracy: 0.9766 - val_loss: 0.0866
# Epoch 178/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - loss: 0.0093 - val_accuracy: 0.9765 - val_loss: 0.0865
# Epoch 179/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9995 - loss: 0.0096 - val_accuracy: 0.9759 - val_loss: 0.0864
# Epoch 180/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9992 - loss: 0.0103 - val_accuracy: 0.9768 - val_loss: 0.0863
# Epoch 181/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9997 - loss: 0.0092 - val_accuracy: 0.9762 - val_loss: 0.0863
# Epoch 182/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9993 - loss: 0.0097 - val_accuracy: 0.9764 - val_loss: 0.0865
# Epoch 183/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9995 - loss: 0.0090 - val_accuracy: 0.9762 - val_loss: 0.0868
# Epoch 184/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - loss: 0.0089 - val_accuracy: 0.9765 - val_loss: 0.0864
# Epoch 185/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 0.9767 - val_loss: 0.0866
# Epoch 186/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0088 - val_accuracy: 0.9766 - val_loss: 0.0868
# Epoch 187/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - loss: 0.0093 - val_accuracy: 0.9767 - val_loss: 0.0868
# Epoch 188/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9997 - loss: 0.0085 - val_accuracy: 0.9769 - val_loss: 0.0870
# Epoch 189/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0085 - val_accuracy: 0.9762 - val_loss: 0.0869
# Epoch 190/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - loss: 0.0087 - val_accuracy: 0.9764 - val_loss: 0.0870
# Epoch 191/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - loss: 0.0086 - val_accuracy: 0.9770 - val_loss: 0.0873
# Epoch 192/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - loss: 0.0088 - val_accuracy: 0.9766 - val_loss: 0.0873
# Epoch 193/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9997 - loss: 0.0078 - val_accuracy: 0.9766 - val_loss: 0.0875
# Epoch 194/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9997 - loss: 0.0084 - val_accuracy: 0.9765 - val_loss: 0.0875
# Epoch 195/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0084 - val_accuracy: 0.9768 - val_loss: 0.0876
# Epoch 196/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0083 - val_accuracy: 0.9764 - val_loss: 0.0875
# Epoch 197/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0079 - val_accuracy: 0.9766 - val_loss: 0.0871
# Epoch 198/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0079 - val_accuracy: 0.9764 - val_loss: 0.0878
# Epoch 199/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9996 - loss: 0.0078 - val_accuracy: 0.9768 - val_loss: 0.0872
# Epoch 200/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9997 - loss: 0.0077 - val_accuracy: 0.9763 - val_loss: 0.0873
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.9740 - loss: 0.0869
# Test Loss: 0.07431421428918839
# Test Accuracy: 0.9775000214576721

# %% [markdown]
# ### The Keras Implementation Turned out to be better because of the following
#
# - Optimized backend libraries
# - Pre-Build Layers
# - Automatic Differentiation
# - Built-in Optimization
# - Better Starting weights
#
# ### Reasons Why the Scratch implementation didnt perform well
#
# - Hyperparameter Tuning
# - Limited Optimization
# - Limited Regularization Techniques
