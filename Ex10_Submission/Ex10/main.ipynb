# %%
import pandas as pd

# Preprocessing the dataset
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
dataset = dataset.fillna(0)

transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i, j]) for j in range(0, 20)])

# %%
# Implementing the Apriori algorithm
def create_candidates(transactions):
    """Create initial candidate itemsets from transactions."""
    candidates = set()
    for transaction in transactions:
        for item in transaction:
            candidates.add(frozenset([item]))
    return list(candidates)

# %%
def frequent_itemsets(transactions, min_support):
    """Generate frequent itemsets from transactions."""
    candidate_itemsets = create_candidates(transactions)
    itemsets_with_support = {}
    
    while candidate_itemsets:
        frequent_itemsets = []
        for itemset in candidate_itemsets:
            support = calculate_support(transactions, itemset)
            if support >= min_support:
                itemsets_with_support[itemset] = support
                frequent_itemsets.append(itemset)
        
        if not frequent_itemsets:
            break
        
        candidate_itemsets = generate_candidates(frequent_itemsets)
    
    return itemsets_with_support

# %%
def calculate_support(transactions, itemset):
    """Calculate support for an itemset in transactions."""
    count = 0
    for transaction in transactions:
        if itemset.issubset(transaction):
            count += 1
    return count / len(transactions)

# %%
def generate_candidates(frequent_itemsets):
    """Generate candidate itemsets from frequent itemsets."""
    candidates = set()
    for i in range(len(frequent_itemsets)):
        for j in range(i+1, len(frequent_itemsets)):
            itemset1 = frequent_itemsets[i]
            itemset2 = frequent_itemsets[j]
            union = itemset1.union(itemset2)
            if len(union) == len(itemset1) + 1:
                candidates.add(union)
    return list(candidates)

# %%
min_support = 0.03
frequent_itemsets = frequent_itemsets(transactions, min_support)
for itemset, support in frequent_itemsets.items():
    print(f"Itemset: {itemset}, Support: {support}")
# Out:
# Itemset: frozenset({'ground beef'}), Support: 0.09825356619117451
# Itemset: frozenset({'salmon'}), Support: 0.04252766297826956
# Itemset: frozenset({'chicken'}), Support: 0.05999200106652446
# Itemset: frozenset({'eggs'}), Support: 0.17970937208372217
# Itemset: frozenset({'butter'}), Support: 0.030129316091187842
# Itemset: frozenset({'brownies'}), Support: 0.03372883615517931
# Itemset: frozenset({'honey'}), Support: 0.047460338621517134
# Itemset: frozenset({'fresh bread'}), Support: 0.043060925209972005
# Itemset: frozenset({'burgers'}), Support: 0.0871883748833489
# Itemset: frozenset({'cookies'}), Support: 0.08038928142914278
# Itemset: frozenset({'avocado'}), Support: 0.03332888948140248
# Itemset: frozenset({'shrimp'}), Support: 0.07145713904812692
# Itemset: frozenset({'cake'}), Support: 0.08105585921877083
# Itemset: frozenset({'tomatoes'}), Support: 0.06839088121583789
# Itemset: frozenset({'chocolate'}), Support: 0.1638448206905746
# Itemset: frozenset({'cooking oil'}), Support: 0.0510598586855086
# Itemset: frozenset({'cottage cheese'}), Support: 0.03186241834422077
# Itemset: frozenset({'turkey'}), Support: 0.06252499666711105
# Itemset: frozenset({'olive oil'}), Support: 0.0658578856152513
# Itemset: frozenset({'green tea'}), Support: 0.13211571790427942
# Itemset: frozenset({'herb & pepper'}), Support: 0.04946007199040128
# Itemset: frozenset({'soup'}), Support: 0.05052659645380616
# Itemset: frozenset({'escalope'}), Support: 0.0793227569657379
# Itemset: frozenset({'grated cheese'}), Support: 0.0523930142647647
# Itemset: frozenset({'spaghetti'}), Support: 0.17411011865084655
# Itemset: frozenset({'mineral water'}), Support: 0.23836821757099053
# Itemset: frozenset({'low fat yogurt'}), Support: 0.07652313024930009
# Itemset: frozenset({'0'}), Support: 0.9998666844420744
# Itemset: frozenset({'pancakes'}), Support: 0.09505399280095987
# Itemset: frozenset({'tomato juice'}), Support: 0.030395947207039063
# Itemset: frozenset({'frozen smoothie'}), Support: 0.06332489001466471
# Itemset: frozenset({'frozen vegetables'}), Support: 0.09532062391681109
# Itemset: frozenset({'hot dogs'}), Support: 0.03239568057592321
# Itemset: frozenset({'whole wheat rice'}), Support: 0.058525529929342755
# Itemset: frozenset({'milk'}), Support: 0.12958272230369283
# Itemset: frozenset({'champagne'}), Support: 0.04679376083188908
# Itemset: frozenset({'french fries'}), Support: 0.1709105452606319
# Itemset: frozenset({'chocolate', '0'}), Support: 0.1638448206905746
# Itemset: frozenset({'chocolate', 'french fries'}), Support: 0.03439541394480736
# Itemset: frozenset({'chocolate', 'eggs'}), Support: 0.03319557392347687
# Itemset: frozenset({'0', 'whole wheat rice'}), Support: 0.058525529929342755
# Itemset: frozenset({'mineral water', 'frozen vegetables'}), Support: 0.03572856952406346
# Itemset: frozenset({'spaghetti', 'milk'}), Support: 0.03546193840821224
# Itemset: frozenset({'0', 'shrimp'}), Support: 0.0713238234902013
# Itemset: frozenset({'ground beef', 'mineral water'}), Support: 0.040927876283162246
# Itemset: frozenset({'mineral water', 'eggs'}), Support: 0.05092654312758299
# Itemset: frozenset({'0', 'cake'}), Support: 0.08105585921877083
# Itemset: frozenset({'0', 'turkey'}), Support: 0.06252499666711105
# Itemset: frozenset({'ground beef', 'spaghetti'}), Support: 0.03919477403012932
# Itemset: frozenset({'0', 'tomatoes'}), Support: 0.06839088121583789
# Itemset: frozenset({'0', 'spaghetti'}), Support: 0.17411011865084655
# Itemset: frozenset({'0', 'low fat yogurt'}), Support: 0.07638981469137449
# Itemset: frozenset({'0', 'green tea'}), Support: 0.13198240234635383
# Itemset: frozenset({'0', 'frozen smoothie'}), Support: 0.0631915744567391
# Itemset: frozenset({'0', 'frozen vegetables'}), Support: 0.09532062391681109
# Itemset: frozenset({'0', 'burgers'}), Support: 0.0871883748833489
# Itemset: frozenset({'0', 'ground beef'}), Support: 0.09825356619117451
# Itemset: frozenset({'chocolate', 'milk'}), Support: 0.03212904946007199
# Itemset: frozenset({'cooking oil', '0'}), Support: 0.0510598586855086
# Itemset: frozenset({'milk', 'eggs'}), Support: 0.03079589388081589
# Itemset: frozenset({'0', 'soup'}), Support: 0.05052659645380616
# Itemset: frozenset({'chocolate', 'spaghetti'}), Support: 0.03919477403012932
# Itemset: frozenset({'0', 'mineral water'}), Support: 0.23823490201306494
# Itemset: frozenset({'0', 'grated cheese'}), Support: 0.0523930142647647
# Itemset: frozenset({'0', 'pancakes'}), Support: 0.09505399280095987
# Itemset: frozenset({'0', 'hot dogs'}), Support: 0.03239568057592321
# Itemset: frozenset({'0', 'milk'}), Support: 0.12958272230369283
# Itemset: frozenset({'0', 'french fries'}), Support: 0.1709105452606319
# Itemset: frozenset({'french fries', 'eggs'}), Support: 0.036395147313691506
# Itemset: frozenset({'0', 'chicken'}), Support: 0.05999200106652446
# Itemset: frozenset({'0', 'fresh bread'}), Support: 0.043060925209972005
# Itemset: frozenset({'chocolate', 'mineral water'}), Support: 0.05265964538061592
# Itemset: frozenset({'mineral water', 'green tea'}), Support: 0.03106252499666711
# Itemset: frozenset({'0', 'brownies'}), Support: 0.03372883615517931
# Itemset: frozenset({'0', 'cottage cheese'}), Support: 0.03172910278629516
# Itemset: frozenset({'mineral water', 'pancakes'}), Support: 0.03372883615517931
# Itemset: frozenset({'0', 'herb & pepper'}), Support: 0.04946007199040128
# Itemset: frozenset({'mineral water', 'french fries'}), Support: 0.03372883615517931
# Itemset: frozenset({'spaghetti', 'eggs'}), Support: 0.036528462871617116
# Itemset: frozenset({'mineral water', 'milk'}), Support: 0.04799360085321957
# Itemset: frozenset({'0', 'eggs'}), Support: 0.17970937208372217
# Itemset: frozenset({'0', 'butter'}), Support: 0.030129316091187842
# Itemset: frozenset({'0', 'salmon'}), Support: 0.04239434742034395
# Itemset: frozenset({'spaghetti', 'mineral water'}), Support: 0.05972536995067324
# Itemset: frozenset({'0', 'avocado'}), Support: 0.03319557392347687
# Itemset: frozenset({'0', 'champagne'}), Support: 0.04679376083188908
# Itemset: frozenset({'0', 'escalope'}), Support: 0.0793227569657379
# Itemset: frozenset({'0', 'honey'}), Support: 0.047327023063591524
# Itemset: frozenset({'0', 'cookies'}), Support: 0.08038928142914278
# Itemset: frozenset({'0', 'olive oil'}), Support: 0.0657245700573257
# Itemset: frozenset({'0', 'tomato juice'}), Support: 0.030262631649113452
# Itemset: frozenset({'0', 'mineral water', 'frozen vegetables'}), Support: 0.03572856952406346
# Itemset: frozenset({'0', 'spaghetti', 'mineral water'}), Support: 0.05972536995067324
# Itemset: frozenset({'0', 'mineral water', 'french fries'}), Support: 0.03372883615517931
# Itemset: frozenset({'0', 'mineral water', 'milk'}), Support: 0.04799360085321957
# Itemset: frozenset({'0', 'ground beef', 'spaghetti'}), Support: 0.03919477403012932
# Itemset: frozenset({'0', 'spaghetti', 'eggs'}), Support: 0.036528462871617116
# Itemset: frozenset({'chocolate', '0', 'french fries'}), Support: 0.03439541394480736
# Itemset: frozenset({'0', 'french fries', 'eggs'}), Support: 0.036395147313691506
# Itemset: frozenset({'0', 'mineral water', 'green tea'}), Support: 0.0309292094387415
# Itemset: frozenset({'0', 'mineral water', 'eggs'}), Support: 0.05092654312758299
# Itemset: frozenset({'0', 'spaghetti', 'milk'}), Support: 0.03546193840821224
# Itemset: frozenset({'chocolate', '0', 'eggs'}), Support: 0.03319557392347687
# Itemset: frozenset({'chocolate', 'spaghetti', '0'}), Support: 0.03919477403012932
# Itemset: frozenset({'chocolate', '0', 'milk'}), Support: 0.03212904946007199
# Itemset: frozenset({'0', 'milk', 'eggs'}), Support: 0.03079589388081589
# Itemset: frozenset({'chocolate', 'mineral water', '0'}), Support: 0.05265964538061592
# Itemset: frozenset({'0', 'ground beef', 'mineral water'}), Support: 0.040927876283162246
# Itemset: frozenset({'0', 'mineral water', 'pancakes'}), Support: 0.03372883615517931
